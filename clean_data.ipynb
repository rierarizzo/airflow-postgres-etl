# %%
import requests

url = "https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2026-04.parquet"
local_path = "./datasets/green_tripdata_2026-04.parquet"

# %%
response = requests.get(url)
with open(local_path, "wb") as f:
    f.write(response.content)

# %%
import pandas as pd

df = pd.read_parquet(local_path, engine="fastparquet")

df.head()
# Out:
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0         2  2026-04-01 00:29:09   2026-04-01 00:54:48                  N
# 1         2  2026-04-01 00:19:13   2026-04-01 00:19:20                  N
# 2         2  2026-04-01 00:40:24   2026-04-01 00:47:31                  N
# 3         2  2026-04-01 00:27:31   2026-04-01 00:35:33                  N
# 4         2  2026-04-01 00:51:45   2026-04-01 00:58:33                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0         1.0            66            48              1.0           6.56
# 1         5.0           129           129              1.0           0.00
# 2         1.0            74           141              1.0           2.56
# 3         1.0           244           116              1.0           1.48
# 4         1.0           243           235              1.0           0.93
#
#    fare_amount  ...  mta_tax  tip_amount  tolls_amount  ehail_fee  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 44238 entries, 0 to 44237
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   VendorID               44238 non-null  int32
#  1   lpep_pickup_datetime   44238 non-null  datetime64[us]
#  2   lpep_dropoff_datetime  44238 non-null  datetime64[us]
#  3   store_and_fwd_flag     37948 non-null  object
#  4   RatecodeID             37948 non-null  float64
#  5   PULocationID           44238 non-null  int32
#  6   DOLocationID           44238 non-null  int32
#  7   passenger_count        37948 non-null  float64
#  8   trip_distance          44238 non-null  float64
#  9   fare_amount            44238 non-null  float64
#  10  extra                  44238 non-null  float64
#  11  mta_tax                44238 non-null  float64
#  12  tip_amount             44238 non-null  float64
#  13  tolls_amount           44238 non-null  float64
# ...

# %%
df.describe()
# Out:
#            VendorID        lpep_pickup_datetime       lpep_dropoff_datetime  \
# count  44238.000000                       44238                       44238
# mean       2.366563  2026-04-16 10:30:38.139970  2026-04-16 10:52:03.452009
# min        1.000000         2026-03-31 23:28:50         2026-04-01 00:15:53
# 25%        2.000000  2026-04-08 21:09:39.500000  2026-04-08 21:28:00.500000
# 50%        2.000000         2026-04-16 14:02:02         2026-04-16 14:20:35
# 75%        2.000000  2026-04-23 17:24:28.500000  2026-04-23 17:48:54.750000
# max        6.000000         2026-05-01 07:53:18         2026-05-02 07:07:21
# std        1.313831                         NaN                         NaN
#
#          RatecodeID  PULocationID  DOLocationID  passenger_count  \
# count  37948.000000  44238.000000  44238.000000     37948.000000
# mean       1.245915     98.236222    143.833266         1.316090
# min        1.000000      1.000000      1.000000         0.000000
# ...

# %%
filtered_df = df[
    (df["passenger_count"] > 0) & (df["fare_amount"] > 0) & (df["total_amount"] > 0)
]
filtered_df.describe()
# Out:
#            VendorID        lpep_pickup_datetime       lpep_dropoff_datetime  \
# count  37227.000000                       37227                       37227
# mean       1.921347  2026-04-16 12:06:31.600934  2026-04-16 12:26:29.588658
# min        1.000000         2026-03-31 23:28:50         2026-04-01 00:15:53
# 25%        2.000000  2026-04-08 23:40:04.500000  2026-04-09 00:07:11.500000
# 50%        2.000000         2026-04-16 16:08:55         2026-04-16 16:36:09
# 75%        2.000000  2026-04-23 18:17:54.500000  2026-04-23 18:34:58.500000
# max        2.000000         2026-05-01 07:53:18         2026-05-02 07:07:21
# std        0.269199                         NaN                         NaN
#
#          RatecodeID  PULocationID  DOLocationID  passenger_count  \
# count  37227.000000  37227.000000  37227.000000     37227.000000
# mean       1.239128     94.463561    146.634244         1.335079
# min        1.000000      1.000000      1.000000         1.000000
# ...
